# %%
pip install pypdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from bs4 import BeautifulSoup
import pypdf  # Installed via pip install pypdf

def clean_csv_using_pdf(pdf_path, csv_path):
    """Extract cleaning instructions from PDF and apply to CSV"""
    # Load attachments into working environment
    pdf_text = extract_pdf_content(pdf_path)
    
    # Load the CSV data
    df = pd.read_csv(csv_path)
    
    # Clean date formats and handle inconsistent data:
    for col in df.columns:
        if 'date' in col.lower():
            try:
                # Placeholder for your custom logic:
                # pdf_has_dates = check_pdf_for_dates(pdf_text)
                pass
            except:
                pass
                
    # Convert salary columns to numeric format:
    try:
        for col in df.columns:
            if any(term in col.lower() for term in ['salary', 'pay', 'hourly']):
                # Placeholder for your custom conversion logic:
                # df[col] = convert_salary_to_numeric(df, col)
                pass
    except Exception as e:
        print(f"Salary conversion error: {str(e)}")
        
    # Remove duplicates and save cleaned version:
    df.drop_duplicates(inplace=True)
    
    # Save the file (Update with your desired export name)
    output_path = "Cleaned_DS_Jobs_AnalysisReady.csv"
    df.to_csv(output_path, index=False)
    print(f"Success! Cleaned data saved to {output_path}")

def extract_pdf_content(pdf_path):
    """Extract text content from a binary PDF file using pypdf"""
    text = ""
    with open(pdf_path, 'rb') as file:  # Open in binary mode ('rb')
        reader = pypdf.PdfReader(file)
        for page in reader.pages:
            text += page.extract_text() or ""
    return text

# Test the cleaning process
if __name__ == '__main__':
    # REPLACE THESE STRINGS WITH YOUR ACTUAL FILE PATHS
    # Do not include < or > characters
    actual_pdf = "problem1.pdf" 
    actual_csv = "Cleaned_DS_Jobs.csv" 
    
    clean_csv_using_pdf(actual_pdf, actual_csv)
# Out:
# Success! Cleaned data saved to Cleaned_DS_Jobs_AnalysisReady.csv
